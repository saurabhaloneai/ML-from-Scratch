# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/16R4pSOyZDiyEXM2nIRRranCrBlR724tT?usp=sharing)

# %% [markdown]
# ##Install and import the library

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %% [markdown]
# ##Mount the drive (if needed)

# %%
# Run this cell if u can't mount ur drive automatically

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Set ur directory

# %%
#set the directory

dir = '/content/drive/MyDrive/cnn'

# %% [markdown]
# ##Download The Image

# %%
downloader.download('blue whale', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/cnn/blue whale
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://3.bp.blogspot.com/-KrSlRqEQv30/UmZa1I6UenI/AAAAAAAAFRU/7c9WjJBjr3k/s1600/Blue-Whale-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://2.bp.blogspot.com/-SnKt1aTTS6Q/UghkijcmV9I/AAAAAAAAEAU/pLRbLfXQreM/s1600/Blue_Whales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.buzzle.com/media/images-en/gallery/mammals/1200-482728893-length-weight.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.whalewatching.com/wp-content/uploads/2017/03/blue-whale.jpg
# [Error]Invalid image, not saving https://www.whalewatching.com/wp-content/uploads/2017/03/blue-whale.jpg
#
# [!] Issue getting: https://www.whalewatching.com/wp-content/uploads/2017/03/blue-whale.jpg
# ...

# %%
downloader.download('humpback whale', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/cnn/humpback whale
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.shared.com/content/images/2017/03/humpback-whale.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thoughtco.com/thmb/l1vhEscfQQUiCi9W8ZpJ79vc144=/5200x3313/filters:fill(auto,1)/humpback-whale-underwater-portrait--107312834-5a01c2cab39d03001952917f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.antarctica.gov.au/site/assets/files/45693/ia40278.1600x0.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://yesofcorsa.com/wp-content/uploads/2017/06/Humpback-Whale-Best-Wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://static2.businessinsider.com/image/540620fe6bb3f7db2c44e2f2-2400/humpback-whale-3.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('beluga whale', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/cnn/beluga whale
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.animalspot.net/wp-content/uploads/2015/04/Beluga-Whale.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.animalspot.net/wp-content/uploads/2015/04/Images-of-Beluga-Whales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://3.bp.blogspot.com/-GdYLiMrxSj0/UdKlKqd6v1I/AAAAAAAAK-8/Q6-0exD-Y7s/s1600/Beluga+Whale.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i2.wp.com/i.huffpost.com/gen/721378/original.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://s.hdnux.com/photos/01/20/02/11/20980305/3/rawImage.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.animalspot.net/wp-content/uploads/2015/04/Beluga-Whale-Images.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('fin whale', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/cnn/fin whale
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.coolantarctica.com/Antarctica fact file/wildlife/whales/Finhval.jpg
# [!] Issue getting: https://www.coolantarctica.com/Antarctica fact file/wildlife/whales/Finhval.jpg
# [!] Error:: URL can't contain control characters. '/Antarctica fact file/wildlife/whales/Finhval.jpg' (found at least ' ')
# [%] Downloading Image #1 from https://www.climate.gov/sites/default/files/AKDeptFishGame_floating_fin_whale_large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://dannykesslerphotography.com/wp-content/uploads/2016/06/fin_whale_side_angle_DKPcom.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://34423738a7249e64bfcb-dab15912e6a178ae1e0a8d552f631d3c.ssl.cf1.rackcdn.com/Chanaral4101-2-4W.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('orca whale', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/cnn/orca whale
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.lifeblab.com/wp-content/uploads/2016/07/e83cb50a2cf6003ecd0b470de7444e90fe76e7d51eb4184497f9c8_640_orca.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn8.dissolve.com/p/D1233_7_726/D1233_7_726_1200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://wallpapersqq.net/wp-content/uploads/2016/01/Orca-Killer-Whale-ocean-2.jpg
# [Error]Invalid image, not saving http://wallpapersqq.net/wp-content/uploads/2016/01/Orca-Killer-Whale-ocean-2.jpg
#
# [!] Issue getting: http://wallpapersqq.net/wp-content/uploads/2016/01/Orca-Killer-Whale-ocean-2.jpg
# [!] Error:: Invalid image, not saving http://wallpapersqq.net/wp-content/uploads/2016/01/Orca-Killer-Whale-ocean-2.jpg
#
# ...

# %%
from IPython.display import Image
Image(filename='/content/drive/MyDrive/cnn/fin whale/Image_1.jpg')

# %%
Image(filename='/content/drive/MyDrive/cnn/blue whale/Image_1.jpg')
